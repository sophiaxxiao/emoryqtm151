# %% [markdown]
# # Assignment 6

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your name below

# %%
print("Sophia Xiao")
# Out:
# Sophia Xiao

# %% [markdown]
# <font size = "5">
#
# Import the "pandas" and "matplotlib.pyplot" library

# %%
# Write your answer here:

import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# (a) Compute function for each individual (map)
#
# <font size = "3">
#
# - Import the datset "data/investment.csv"
# - Write a lambda function for $V = P/(1+r)$.
# - Use ```list(map(...))``` to calculate $V$ for each row of the dataset

# %%
# Write your own code here

investment_dataset = pd.read_csv("data/investment.csv")
print(investment_dataset.columns)

V_func = lambda P, r: P / (1+r)

investment_dataset["V"] = list(map(V_func, investment_dataset["P"],  investment_dataset["r"]))

investment_dataset
# Out:
# Index(['P', 'r'], dtype='object')
#       P     r            V
# 0  1000  0.01   990.099010
# 1  2000  0.02  1960.784314
# 2   500  0.03   485.436893
# 3   800  0.04   769.230769
# 4   400  0.08   370.370370

# %% [markdown]
# <font size = "5">
#
# (b) Convert to upper case
#
# <font size = "3">
#
# - Create the following function to convert a string to upper case
#
# $\quad$ ``` fn_upper = lambda x: x.upper() ```
#
# - Create a new column, "countryname_upper"  <br>
# that converts "countryname" to upper case.

# %%
# Write your own code here
fn_upper = lambda x : x.upper()

WDI2020 = pd.read_csv("data/wdi_2020.csv")

WDI2020["countryname_upper"] = list(map(fn_upper, WDI2020["countryname"]))


WDI2020
# Out:
#      year yearcode                  countryname countrycode  \
# 0    2020   YR2020                  Afghanistan         AFG
# 1    2020   YR2020  Africa Eastern and Southern         AFE
# 2    2020   YR2020   Africa Western and Central         AFW
# 3    2020   YR2020                      Albania         ALB
# 4    2020   YR2020                      Algeria         DZA
# ..    ...      ...                          ...         ...
# 261  2020   YR2020           West Bank and Gaza         PSE
# 262  2020   YR2020                        World         WLD
# 263  2020   YR2020                  Yemen, Rep.         YEM
# 264  2020   YR2020                       Zambia         ZMB
# 265  2020   YR2020                     Zimbabwe         ZWE
#
#      prop_urbanpopulation            countryname_upper
# 0               26.026000                  AFGHANISTAN
# 1               36.828301  AFRICA EASTERN AND SOUTHERN
# 2               47.857831   AFRICA WESTERN AND CENTRAL
# ...

# %% [markdown]
# <font size = "5">
# For questions (b)-(d), read "data/wdi_2020.csv"

# %% [markdown]
# <font size = "5">
#
# (c) Extract sorted elements from a dataset
#
# <font size = "3">
#
# - Sort by "prop_urbanpopulation" in descending order
# - Subset the 5 countries with the highest urban population

# %%
# Write your code here
WDI2020.sort_values("prop_urbanpopulation", ascending = False, inplace = True)

WDI2020

highest_5_countries = WDI2020.iloc[:5, :] # slice row 0-5 and all columns 

highest_5_countries
# Out:
#      year yearcode           countryname countrycode  prop_urbanpopulation  \
# 212  2020   YR2020             Singapore         SGP                 100.0
# 147  2020   YR2020      Macao SAR, China         MAC                 100.0
# 40   2020   YR2020        Cayman Islands         CYM                 100.0
# 90   2020   YR2020             Gibraltar         GIB                 100.0
# 103  2020   YR2020  Hong Kong SAR, China         HKG                 100.0
#
#         countryname_upper
# 212             SINGAPORE
# 147      MACAO SAR, CHINA
# 40         CAYMAN ISLANDS
# 90              GIBRALTAR
# 103  HONG KONG SAR, CHINA

# %% [markdown]
# <font size = "5">
#
# (d) Subset elements with query
#
# <font size = "3">
#
# - Compute the median of "prop_urbanpopulation"
# - Use ".query()" to subset countries with <br>
#  "prop_urbanpopulation" above the median

# %%
# Write your own code here

median_prop_urbanpopulation = WDI2020["prop_urbanpopulation"].median() 
# the .median method for the pd dataframe column disregards NaN values.
print(median_prop_urbanpopulation)

above_average_urban_population = WDI2020.query("prop_urbanpopulation > @median_prop_urbanpopulation")
# use a boolean statement in parentheses. No need to use parentheses for variable name.

above_average_urban_population
# Out:
# 60.69872843
#      year yearcode                                        countryname  \
# 212  2020   YR2020                                          Singapore
# 147  2020   YR2020                                   Macao SAR, China
# 40   2020   YR2020                                     Cayman Islands
# 90   2020   YR2020                                          Gibraltar
# 103  2020   YR2020                               Hong Kong SAR, China
# ..    ...      ...                                                ...
# 3    2020   YR2020                                            Albania
# 84   2020   YR2020                                   French Polynesia
# 160  2020   YR2020  Middle East & North Africa (excluding high inc...
# 161  2020   YR2020  Middle East & North Africa (IDA & IBRD countries)
# 46   2020   YR2020                                              China
#
#     countrycode  prop_urbanpopulation  \
# 212         SGP            100.000000
# ...

# %% [markdown]
# <font size = "5">
#
# (e) Plot by category
#
# <font size = "3">
#
# - Read "data/wdi_urban.csv"<br>
# This contains data from 1980 and 2020
#
# - Create a list with the unique values of "year"
# - Create a plot with a ...
#     - Histogram of "prop_urbanpopulation" <br>
#     for each year
#     - Set the histogram option ``` alpha = 0.5 ``` for transparency
#     - All the histograms should be overlapping
#     - Create a legend with the list of years
#     - Label the axes and the title
#
# What do we learn from the graph?
#
# Compared to in 1980, in 2020 more countries had a higher proportion of their populations living in cities. This makes sense because development is accompanied by urbanization.
#
# HINT: See the example at the end of Lecture 10

# %%
WDIURBAN = pd.read_csv("data/wdi_urban.csv")

# Get unique categories for "year"
unique_years = pd.unique(WDIURBAN["year"])

# Use a for loop to plot a scatter plot between "weight" and "acceleration"
# for each category. Each plot  will have a different color

for category in unique_years:
    df   = WDIURBAN.query("year == @category")
    plt.hist(df["prop_urbanpopulation"], alpha = 0.5)

# Add labels and a legends    
plt.xlabel("Proportion Of Urban Population")
plt.ylabel("Count")
plt.legend(labels = unique_years,
           title  = "Year")
plt.title("Proportion Urban Population Distribution for 1980 and 2020 (from WDI)")

plt.show()
