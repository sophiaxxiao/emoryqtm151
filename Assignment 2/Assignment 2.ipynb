# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your name:

# %%
print("Sophia Xiao")

# %% [markdown]
# <font size = "5">
#
# (a) Import the pandas and matplotlib packages

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# (b) Open the dataset "worldbank_wdi_2019.csv" in the "data" folder
#
# <font size = "3">
#
# - Read it as a pandas object called "wdi"
# - Note: This is a subset of the World Development Indicators for 2019

# %%
wdi = pd.read_csv("/Users/sophiaxiao/Downloads/Assignment 2/data/worldbank_wdi_2019.csv")
# Input the path to the csv as a string argument in the read_csv function

# %% [markdown]
# <font size = "5">
#
# (c) View the dataset and create a list of variable names

# %%
# Create a list, e.g. "variable_names = [ "name1", "name2", "name3" ]"

variables = list(wdi.columns)

# Manually type the names of the 5 variables
# 'year', 'country_name', 'life_expectancy', 'gdp_per_capita_usd'
# Out:
# ['year', 'country_name', 'life_expectancy', 'gdp_per_capita_usd']

# %% [markdown]
# <font size = "5">
#
# (d) Compute descriptive statistics for the fifth variable in the dataset
#
# <font size = "3">
#
# - One way to do this is:
#
# wdi["gdp_per_capita_usd"].describe()
#
# - Do something similar, but substitute "gdp_per_capita_usd" with a command that automatically extracts the fifth element in the list

# %%
wdi[variables[3]].describe()
# access pd dataframe column with square brackets. 
# using .describe() method to generate summary statistics.
# Out:
# count       255.000000
# mean      17230.949757
# std       25792.183785
# min         216.972968
# 25%        2186.046581
# 50%        6837.717826
# 75%       19809.323135
# max      199377.481800
# Name: gdp_per_capita_usd, dtype: float64

# %% [markdown]
# <font size = "5">
#
# (e) Show a scatter plot that shows "gdp_per_capita_usd" in the x-axis and "life_expectancy" in the y-axis.
#
# <font size = "3">
#
# - Label the axes for full points
# - Note: This question does not depend on (d)

# %%
plt.scatter(wdi["gdp_per_capita_usd"], wdi["life_expectancy"], color = "purple")
plt.xlabel("GDP per capita (USD)")
plt.ylabel("Avg life expectancy (years)")
plt.title("2019 WDI GDP Per Capita vs Life Expectancy")
plt.show()
